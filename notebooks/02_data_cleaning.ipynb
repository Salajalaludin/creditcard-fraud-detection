# %% [markdown]
# # 02 — Data Cleaning
# Mengaudit missing values dan menghapus exact duplicates sebelum splitting untuk mencegah leakage.

# %%
# Menentukan root project dan mendaftarkan folder source code lokal.
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# Memuat data tervalidasi, lalu menghapus hanya exact duplicates.
from fraud_detection.config import DEFAULT_DATA_PATH
from fraud_detection.data import clean_transactions, load_transactions
raw = load_transactions(DEFAULT_DATA_PATH)
clean, quality = clean_transactions(raw)

# Menampilkan audit sebelum dan sesudah cleaning.
quality
# Out:
# {'rows_raw': 284807,
#  'columns': 31,
#  'missing_cells': 0,
#  'exact_duplicates': 1081,
#  'fraud_count_raw': 492,
#  'normal_count_raw': 284315,
#  'fraud_rate_raw': 0.001727485630620034,
#  'rows_clean': 283726,
#  'duplicates_removed': 1081,
#  'fraud_count_clean': 473,
#  'normal_count_clean': 283253,
#  'fraud_rate_clean': 0.001667101358352777}

# %%
# Assertion menghentikan notebook jika cleaning tidak sesuai harapan.
assert clean.isna().sum().sum() == 0
assert clean.duplicated().sum() == 0

# Menampilkan dimensi akhir dataset bersih.
clean.shape
# Out:
# (283726, 31)
