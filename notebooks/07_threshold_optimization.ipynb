# %% [markdown]
# # 07 — Threshold Optimization
# Memilih threshold pada validation set dan mengevaluasinya satu kali pada test set.

# %%
# Menjalankan threshold optimization, risk scoring, dan queue generation.
from pathlib import Path
import subprocess, sys, json
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
subprocess.run([sys.executable, str(ROOT / 'scripts' / 'optimize_threshold.py')], cwd=ROOT, check=True)

# %%
# Membandingkan rekomendasi statistik dan skenario biaya.
pd.read_csv(ROOT / 'reports' / 'threshold_recommendations.csv')[['strategy', 'threshold', 'precision', 'recall', 'f1', 'alerts']]

# %%
# Menampilkan metrik final test pada threshold terpilih.
json.loads((ROOT / 'reports' / 'threshold_test_metrics.json').read_text(encoding='utf-8'))
