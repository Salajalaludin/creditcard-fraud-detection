# %% [markdown]
# # 04 — Feature Engineering
# Membuat transformasi Amount dan Time yang transparan tanpa mengubah data mentah.

# %%
# Menentukan root project dan memuat fungsi feature engineering reusable.
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from fraud_detection.config import DEFAULT_DATA_PATH
from fraud_detection.data import load_transactions
from fraud_detection.feature_engineering import add_engineered_features
data = load_transactions(DEFAULT_DATA_PATH)
engineered = add_engineered_features(data)
engineered[['Time', 'Amount', 'Amount_Log', 'Hour', 'Time_Period', 'Amount_Group']].head()

# %%
# Memeriksa distribusi fitur kategori baru terhadap target.
engineered.groupby('Time_Period', observed=False)['Class'].agg(['count', 'sum', 'mean'])
