# %% [markdown]
# # 06 — Model Comparison
# Membandingkan class weighting, undersampling, SMOTE, Random Forest, dan boosting menggunakan validation PR-AUC.

# %%
# Menentukan root project dan menjalankan pipeline comparison yang reproducible.
from pathlib import Path
import subprocess, sys
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
subprocess.run([sys.executable, str(ROOT / 'scripts' / 'train_model_comparison.py')], cwd=ROOT, check=True)

# %%
# Membaca hasil dan mengurutkan kandidat validation berdasarkan PR-AUC.
metrics = pd.read_csv(ROOT / 'reports' / 'model_comparison_metrics.csv')
metrics.sort_values(['split', 'pr_auc'], ascending=[True, False])
